# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Second Edition](https://www.manning.com/books/deep-learning-with-python-second-edition?a_aid=keras&a_bid=76564dff). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# This notebook was generated for TensorFlow 2.6.

# %% [markdown]
# # Introduction to deep learning for computer vision

# %% [markdown]
# ## Introduction to convnets

# %% [markdown]
# **Instantiating a small convnet**

# %%
from tensorflow import keras
from tensorflow.keras import layers
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# **Displaying the model's summary**

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 128)         73856
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 10)                11530
#
# =================================================================
# Total params: 104202 (407.04 KB)
# Trainable params: 104202 (407.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Training the convnet on MNIST images**

# %%
from tensorflow.keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype("float32") / 255
model.compile(optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"])
model.fit(train_images, train_labels, epochs=5, batch_size=2024)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/5
# 30/30 [==============================] - 13s 45ms/step - loss: 1.0366 - accuracy: 0.6862
# Epoch 2/5
# 30/30 [==============================] - 1s 28ms/step - loss: 0.3531 - accuracy: 0.8923
# Epoch 3/5
# 30/30 [==============================] - 1s 28ms/step - loss: 0.2280 - accuracy: 0.9312
# Epoch 4/5
# 30/30 [==============================] - 1s 27ms/step - loss: 0.1595 - accuracy: 0.9511
# Epoch 5/5
# 30/30 [==============================] - 1s 27ms/step - loss: 0.1218 - accuracy: 0.9621

# %% [markdown]
# **Evaluating the convnet**

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1014 - accuracy: 0.9683
# Test accuracy: 0.968

# %% [markdown]
# ### The convolution operation

# %% [markdown]
# #### Understanding border effects and padding

# %% [markdown]
# #### Understanding convolution strides

# %% [markdown]
# ### The max-pooling operation

# %% [markdown]
# **An incorrectly structured convnet missing its max-pooling layers**

# %%
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model_no_max_pool = keras.Model(inputs=inputs, outputs=outputs)

# %%
model_no_max_pool.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_3 (Conv2D)           (None, 26, 26, 32)        320
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 22, 22, 128)       73856
#
#  flatten_1 (Flatten)         (None, 61952)             0
#
#  dense_1 (Dense)             (None, 10)                619530
#
# =================================================================
# Total params: 712202 (2.72 MB)
# Trainable params: 712202 (2.72 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Training a convnet from scratch on a small dataset

# %% [markdown]
# ### The relevance of deep learning for small-data problems

# %% [markdown]
# ### Downloading the data

# %% [markdown]
# **Copying images to training, validation, and test directories**

# %%
#import os, shutil, pathlib

#original_dir = pathlib.Path("train")
#new_base_dir = pathlib.Path("cats_vs_dogs_small")
#def make_subset(subset_name, start_index, end_index):
#    for category in ("cat", "dog"):
#        dir = new_base_dir / subset_name / category
#        os.makedirs(dir)
#        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
#        for fname in fnames:
#            shutil.copyfile(src=original_dir / fname,
#                            dst=dir / fname)

#make_subset("train", start_index=0, end_index=1000)
#make_subset("validation", start_index=1000, end_index=1500)
#make_subset("test", start_index=1500, end_index=2500)

# %% [markdown]
# ### Building the model

# %% [markdown]
# **Instantiating a small convnet for dogs vs. cats classification**

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling (Rescaling)                │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 178, 178, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 89, 89, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 87, 87, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 43, 43, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 41, 41, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 20, 20, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 18, 18, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 9, 9, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 7, 7, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 12544)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │          12,545 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 991,041 (3.78 MB)
#  Trainable params: 991,041 (3.78 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Configuring the model for training**

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# ### Data preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
new_base_dir = '/content/drive/MyDrive/Deep_Learning_files'
# train_dir = '/content/drive/MyDrive/Deep_Learning_files/train'
# validation_dir = '/content/drive/MyDrive/Deep_Learning_files/validation'
# test_dir = '/content/drive/MyDrive/Deep_Learning_files/test'

# %% [markdown]
# **Using `image_dataset_from_directory` to read images**

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    new_base_dir +"/train",
    image_size=(180, 180),
    batch_size=256)
validation_dataset = image_dataset_from_directory(
    new_base_dir + "/validation",
    image_size=(180, 180),
    batch_size=256)
test_dataset = image_dataset_from_directory(
    new_base_dir +"/test",
    image_size=(180, 180),
    batch_size=256)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.

# %% [markdown]
# **Displaying the shapes of the data and labels yielded by the `Dataset`**

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (256, 180, 180, 3)
# labels batch shape: (256,)

# %% [markdown]
# **Fitting the model using a `Dataset`**
# The first epoch can take more time as it will store images into its RAM. After first epoch the other epoch will take relatively very short time.

# %%
from tensorflow import keras
from tensorflow.keras import layers
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 878s 116s/step - accuracy: 0.5044 - loss: 0.6986 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 2/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - accuracy: 0.5332 - loss: 0.6927 - val_accuracy: 0.5030 - val_loss: 0.6914
# Epoch 3/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.5136 - loss: 0.6901 - val_accuracy: 0.5190 - val_loss: 0.6873
# Epoch 4/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.5448 - loss: 0.6871 - val_accuracy: 0.5000 - val_loss: 0.7729
# Epoch 5/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.4969 - loss: 0.7232 - val_accuracy: 0.5080 - val_loss: 0.6894
# Epoch 6/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.5698 - loss: 0.6848 - val_accuracy: 0.5010 - val_loss: 0.6981
# Epoch 7/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.5623 - loss: 0.6872 - val_accuracy: 0.5100 - val_loss: 0.6989
# Epoch 8/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.5383 - loss: 0.6935 - val_accuracy: 0.5450 - val_loss: 0.6734
# Epoch 9/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.5824 - loss: 0.6790 - val_accuracy: 0.6160 - val_loss: 0.6770
# Epoch 10/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.6048 - loss: 0.6711 - val_accuracy: 0.6380 - val_loss: 0.6625
# Epoch 11/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.6504 - loss: 0.6514 - val_accuracy: 0.6460 - val_loss: 0.6316
# Epoch 12/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.6339 - loss: 0.6998 - val_accuracy: 0.6260 - val_loss: 0.6537
# Epoch 13/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6507 - loss: 0.6392 - val_accuracy: 0.6200 - val_loss: 0.6502
# Epoch 14/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6655 - loss: 0.6291 - val_accuracy: 0.6580 - val_loss: 0.6293
# Epoch 15/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.6768 - loss: 0.6146 - val_accuracy: 0.5070 - val_loss: 0.9050
# Epoch 16/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.6233 - loss: 0.7209 - val_accuracy: 0.6620 - val_loss: 0.6158
# Epoch 17/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.6835 - loss: 0.6026 - val_accuracy: 0.6500 - val_loss: 0.6133
# Epoch 18/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.6876 - loss: 0.5915 - val_accuracy: 0.6510 - val_loss: 0.6250
# Epoch 19/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.6771 - loss: 0.6032 - val_accuracy: 0.6690 - val_loss: 0.6153
# Epoch 20/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7035 - loss: 0.5718 - val_accuracy: 0.5590 - val_loss: 0.7374
# Epoch 21/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.6320 - loss: 0.6681 - val_accuracy: 0.5940 - val_loss: 0.8171
# Epoch 22/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.6367 - loss: 0.6747 - val_accuracy: 0.6270 - val_loss: 0.6412
# Epoch 23/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.7024 - loss: 0.5674 - val_accuracy: 0.6950 - val_loss: 0.5753
# Epoch 24/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.6892 - loss: 0.5715 - val_accuracy: 0.7060 - val_loss: 0.5622
# Epoch 25/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.7183 - loss: 0.5439 - val_accuracy: 0.7210 - val_loss: 0.5525
# Epoch 26/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.7120 - loss: 0.5586 - val_accuracy: 0.7120 - val_loss: 0.5535
# Epoch 27/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.7659 - loss: 0.4926 - val_accuracy: 0.6960 - val_loss: 0.5647
# Epoch 28/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.7557 - loss: 0.4893 - val_accuracy: 0.7290 - val_loss: 0.5456
# Epoch 29/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.7479 - loss: 0.5020 - val_accuracy: 0.7290 - val_loss: 0.5291
# Epoch 30/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7825 - loss: 0.4594 - val_accuracy: 0.7240 - val_loss: 0.5641

# %% [markdown]
# **Displaying curves of loss and accuracy during training**

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 465s 114s/step - accuracy: 0.6888 - loss: 0.5773
# Test accuracy: 0.698

# %% [markdown]
# ### Using data augmentation

# %% [markdown]
# **Define a data augmentation stage to add to an image model**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %% [markdown]
# **Displaying some randomly augmented training images**

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# **Defining a new convnet that includes image augmentation and dropout**

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# **Training the regularized convnet**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.5082 - loss: 0.7099 - val_accuracy: 0.5000 - val_loss: 0.6926
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.5152 - loss: 0.6928 - val_accuracy: 0.5000 - val_loss: 0.6922
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.5406 - loss: 0.6910 - val_accuracy: 0.5000 - val_loss: 0.6927
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.4849 - loss: 0.7011 - val_accuracy: 0.6020 - val_loss: 0.6903
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.5212 - loss: 0.6916 - val_accuracy: 0.5020 - val_loss: 0.6893
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.4991 - loss: 0.6919 - val_accuracy: 0.5380 - val_loss: 0.6869
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5764 - loss: 0.6848 - val_accuracy: 0.5060 - val_loss: 0.6902
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.5553 - loss: 0.6873 - val_accuracy: 0.5030 - val_loss: 0.6910
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5320 - loss: 0.6873 - val_accuracy: 0.5730 - val_loss: 0.6744
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.5665 - loss: 0.6815 - val_accuracy: 0.5030 - val_loss: 0.6899
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.5774 - loss: 0.6768 - val_accuracy: 0.5920 - val_loss: 0.6819
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.5997 - loss: 0.6753 - val_accuracy: 0.5650 - val_loss: 0.6763
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.6158 - loss: 0.6591 - val_accuracy: 0.6360 - val_loss: 0.6405
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.5904 - loss: 0.6928 - val_accuracy: 0.5510 - val_loss: 0.6784
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.6034 - loss: 0.6593 - val_accuracy: 0.6400 - val_loss: 0.6421
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.6172 - loss: 0.6633 - val_accuracy: 0.5800 - val_loss: 0.6632
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.6315 - loss: 0.6514 - val_accuracy: 0.6300 - val_loss: 0.6413
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.6386 - loss: 0.6360 - val_accuracy: 0.6750 - val_loss: 0.6080
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.6325 - loss: 0.6356 - val_accuracy: 0.6600 - val_loss: 0.6237
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.6310 - loss: 0.6258 - val_accuracy: 0.6600 - val_loss: 0.5966
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.6079 - loss: 0.9901 - val_accuracy: 0.6190 - val_loss: 0.6402
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.6461 - loss: 0.6237 - val_accuracy: 0.6640 - val_loss: 0.6187
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.6632 - loss: 0.6143 - val_accuracy: 0.6760 - val_loss: 0.5937
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7077 - loss: 0.5808 - val_accuracy: 0.6780 - val_loss: 0.5869
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.6737 - loss: 0.6044 - val_accuracy: 0.6940 - val_loss: 0.5758
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7057 - loss: 0.5717 - val_accuracy: 0.5330 - val_loss: 0.8407
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.6118 - loss: 0.6978 - val_accuracy: 0.6980 - val_loss: 0.5771
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.6769 - loss: 0.5841 - val_accuracy: 0.6880 - val_loss: 0.5727
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.6897 - loss: 0.5933 - val_accuracy: 0.6100 - val_loss: 0.6399
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.6695 - loss: 0.6065 - val_accuracy: 0.6700 - val_loss: 0.6251
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.6811 - loss: 0.5949 - val_accuracy: 0.6940 - val_loss: 0.5778
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.6937 - loss: 0.5976 - val_accuracy: 0.6770 - val_loss: 0.5936
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7084 - loss: 0.5716 - val_accuracy: 0.7110 - val_loss: 0.5502
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7351 - loss: 0.5302 - val_accuracy: 0.6690 - val_loss: 0.6053
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7191 - loss: 0.5409 - val_accuracy: 0.7010 - val_loss: 0.5609
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.6952 - loss: 0.5796 - val_accuracy: 0.6660 - val_loss: 0.5916
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7297 - loss: 0.5411 - val_accuracy: 0.5560 - val_loss: 0.8233
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6631 - loss: 0.6400 - val_accuracy: 0.7140 - val_loss: 0.5463
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7409 - loss: 0.5337 - val_accuracy: 0.7240 - val_loss: 0.5326
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.7414 - loss: 0.5327 - val_accuracy: 0.6270 - val_loss: 0.6233
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7029 - loss: 0.5704 - val_accuracy: 0.7280 - val_loss: 0.5271
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7272 - loss: 0.5426 - val_accuracy: 0.7240 - val_loss: 0.5424
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.7405 - loss: 0.5016 - val_accuracy: 0.7160 - val_loss: 0.5661
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7220 - loss: 0.5552 - val_accuracy: 0.7450 - val_loss: 0.5034
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7251 - loss: 0.5310 - val_accuracy: 0.7260 - val_loss: 0.5444
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7572 - loss: 0.5014 - val_accuracy: 0.6900 - val_loss: 0.6167
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.7302 - loss: 0.5376 - val_accuracy: 0.7380 - val_loss: 0.5126
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7635 - loss: 0.4874 - val_accuracy: 0.7390 - val_loss: 0.5269
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7501 - loss: 0.5084 - val_accuracy: 0.7570 - val_loss: 0.4957
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.7526 - loss: 0.4877 - val_accuracy: 0.7420 - val_loss: 0.5242
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.7387 - loss: 0.5156 - val_accuracy: 0.7570 - val_loss: 0.5073
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7697 - loss: 0.4943 - val_accuracy: 0.7430 - val_loss: 0.5193
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.7719 - loss: 0.4799 - val_accuracy: 0.7510 - val_loss: 0.4972
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7612 - loss: 0.4967 - val_accuracy: 0.7500 - val_loss: 0.5001
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7769 - loss: 0.4829 - val_accuracy: 0.7500 - val_loss: 0.5055
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7822 - loss: 0.4544 - val_accuracy: 0.7490 - val_loss: 0.5125
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7630 - loss: 0.4919 - val_accuracy: 0.7590 - val_loss: 0.5015
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7798 - loss: 0.4493 - val_accuracy: 0.7720 - val_loss: 0.4752
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.7585 - loss: 0.5144 - val_accuracy: 0.7650 - val_loss: 0.4907
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7793 - loss: 0.4586 - val_accuracy: 0.7180 - val_loss: 0.5411
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7604 - loss: 0.4933 - val_accuracy: 0.7790 - val_loss: 0.4541
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8113 - loss: 0.4213 - val_accuracy: 0.7740 - val_loss: 0.4624
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7576 - loss: 0.4930 - val_accuracy: 0.7770 - val_loss: 0.4542
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8187 - loss: 0.4145 - val_accuracy: 0.7040 - val_loss: 0.6623
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7135 - loss: 0.5933 - val_accuracy: 0.7640 - val_loss: 0.4635
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8012 - loss: 0.4352 - val_accuracy: 0.7710 - val_loss: 0.4661
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7979 - loss: 0.4284 - val_accuracy: 0.6990 - val_loss: 0.6270
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7683 - loss: 0.5057 - val_accuracy: 0.7270 - val_loss: 0.5284
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8051 - loss: 0.4449 - val_accuracy: 0.7410 - val_loss: 0.5197
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7873 - loss: 0.4593 - val_accuracy: 0.7630 - val_loss: 0.4883
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7930 - loss: 0.4377 - val_accuracy: 0.7920 - val_loss: 0.4446
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7948 - loss: 0.4317 - val_accuracy: 0.7580 - val_loss: 0.4897
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.7826 - loss: 0.4714 - val_accuracy: 0.7960 - val_loss: 0.4369
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8096 - loss: 0.4282 - val_accuracy: 0.7840 - val_loss: 0.4474
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8029 - loss: 0.4252 - val_accuracy: 0.7830 - val_loss: 0.4437
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8017 - loss: 0.4259 - val_accuracy: 0.7880 - val_loss: 0.4495
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8343 - loss: 0.3945 - val_accuracy: 0.7980 - val_loss: 0.4439
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7907 - loss: 0.4340 - val_accuracy: 0.7830 - val_loss: 0.4472
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.8416 - loss: 0.3650 - val_accuracy: 0.7710 - val_loss: 0.4689
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.7804 - loss: 0.4619 - val_accuracy: 0.7560 - val_loss: 0.4791
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8290 - loss: 0.3885 - val_accuracy: 0.7740 - val_loss: 0.4608
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8240 - loss: 0.3872 - val_accuracy: 0.7950 - val_loss: 0.4387
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.8381 - loss: 0.3736 - val_accuracy: 0.7990 - val_loss: 0.4149
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8146 - loss: 0.3991 - val_accuracy: 0.7780 - val_loss: 0.4682
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8278 - loss: 0.3822 - val_accuracy: 0.7620 - val_loss: 0.5117
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7937 - loss: 0.4391 - val_accuracy: 0.7820 - val_loss: 0.4760
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8542 - loss: 0.3356 - val_accuracy: 0.7690 - val_loss: 0.4697
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8293 - loss: 0.3718 - val_accuracy: 0.7780 - val_loss: 0.4456
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8152 - loss: 0.4021 - val_accuracy: 0.8130 - val_loss: 0.4382
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8385 - loss: 0.3506 - val_accuracy: 0.7670 - val_loss: 0.4907
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8352 - loss: 0.3610 - val_accuracy: 0.8060 - val_loss: 0.4570
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8309 - loss: 0.3805 - val_accuracy: 0.8070 - val_loss: 0.4286
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.8349 - loss: 0.3625 - val_accuracy: 0.7910 - val_loss: 0.4664
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.8599 - loss: 0.3457 - val_accuracy: 0.8000 - val_loss: 0.4311
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.8313 - loss: 0.3699 - val_accuracy: 0.8000 - val_loss: 0.4732
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8197 - loss: 0.3805 - val_accuracy: 0.8040 - val_loss: 0.4202
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8377 - loss: 0.3536 - val_accuracy: 0.7970 - val_loss: 0.4321
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8634 - loss: 0.3225 - val_accuracy: 0.8040 - val_loss: 0.4699
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.8113 - loss: 0.4065 - val_accuracy: 0.7860 - val_loss: 0.4557
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8793 - loss: 0.3033 - val_accuracy: 0.8120 - val_loss: 0.4386

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model(
    "convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 632ms/step - accuracy: 0.7985 - loss: 0.4575
# Test accuracy: 0.783

# %% [markdown]
# ## Leveraging a pretrained model

# %% [markdown]
# ### Feature extraction with a pretrained model

# %% [markdown]
# **Instantiating the VGG16 convolutional base**

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(180, 180, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 180, 180, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 180, 180, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 90, 90, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 90, 90, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 90, 90, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 45, 45, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 45, 45, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 45, 45, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 45, 45, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 22, 22, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 22, 22, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 22, 22, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 22, 22, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 11, 11, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 11, 11, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 11, 11, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 11, 11, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 5, 5, 512)           │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Fast feature extraction without data augmentation

# %% [markdown]
# **Extracting the VGG16 features and corresponding labels**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = keras.applications.vgg16.preprocess_input(images)
        features = conv_base.predict(preprocessed_images)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

train_features, train_labels =  get_features_and_labels(train_dataset)
val_features, val_labels =  get_features_and_labels(validation_dataset)
test_features, test_labels =  get_features_and_labels(test_dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2af3d365398d> in <cell line: 13>()
#      11     return np.concatenate(all_features), np.concatenate(all_labels)
#      12
# ---> 13 train_features, train_labels =  get_features_and_labels(train_dataset)
#      14 val_features, val_labels =  get_features_and_labels(validation_dataset)
#      15 test_features, test_labels =  get_features_and_labels(test_dataset)
#
# NameError: name 'train_dataset' is not defined

# %%
train_features.shape
# Out:
# (2000, 5, 5, 512)

# %% [markdown]
# **Defining and training the densely connected classifier**

# %%
inputs = keras.Input(shape=(5, 5, 512))
x = layers.Flatten()(inputs)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
      filepath="feature_extraction.keras",
      save_best_only=True,
      monitor="val_loss")
]
history = model.fit(
    train_features, train_labels,
    epochs=20,
    validation_data=(val_features, val_labels),
    callbacks=callbacks)
# Out:
# Epoch 1/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.8730 - loss: 31.6233 - val_accuracy: 0.9740 - val_loss: 3.2748
# Epoch 2/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9798 - loss: 3.6505 - val_accuracy: 0.9680 - val_loss: 5.3661
# Epoch 3/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9876 - loss: 1.1723 - val_accuracy: 0.9800 - val_loss: 3.2809
# Epoch 4/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9868 - loss: 1.0249 - val_accuracy: 0.9800 - val_loss: 2.7468
# Epoch 5/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9950 - loss: 0.3681 - val_accuracy: 0.9760 - val_loss: 3.9831
# Epoch 6/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9963 - loss: 0.3242 - val_accuracy: 0.9760 - val_loss: 4.5809
# Epoch 7/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9966 - loss: 0.4624 - val_accuracy: 0.9750 - val_loss: 4.3192
# Epoch 8/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9977 - loss: 0.0481 - val_accuracy: 0.9610 - val_loss: 9.9323
# Epoch 9/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9970 - loss: 0.3223 - val_accuracy: 0.9800 - val_loss: 4.9849
# Epoch 10/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9956 - loss: 0.3143 - val_accuracy: 0.9670 - val_loss: 5.2016
# Epoch 11/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9982 - loss: 0.1364 - val_accuracy: 0.9770 - val_loss: 4.8276
# Epoch 12/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9999 - loss: 0.0090 - val_accuracy: 0.9730 - val_loss: 5.8657
# Epoch 13/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9989 - loss: 0.0390 - val_accuracy: 0.9830 - val_loss: 3.5925
# Epoch 14/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9730 - val_loss: 6.2299
# Epoch 15/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9992 - loss: 0.1167 - val_accuracy: 0.9810 - val_loss: 4.6130
# Epoch 16/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9963 - loss: 0.3609 - val_accuracy: 0.9810 - val_loss: 3.7910
# Epoch 17/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9993 - loss: 0.0265 - val_accuracy: 0.9770 - val_loss: 5.1282
# Epoch 18/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.0768e-16 - val_accuracy: 0.9770 - val_loss: 5.1282
# Epoch 19/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9982 - loss: 0.0871 - val_accuracy: 0.9740 - val_loss: 5.7608
# Epoch 20/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9989 - loss: 0.1122 - val_accuracy: 0.9830 - val_loss: 4.8185

# %% [markdown]
# **Plotting the results**

# %%
import matplotlib.pyplot as plt
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# #### Feature extraction together with data augmentation

# %% [markdown]
# **Instantiating and freezing the VGG16 convolutional base**

# %%
conv_base  = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False)
conv_base.trainable = False

# %% [markdown]
# **Adding a data augmentation stage and a classifier to the convolutional base**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 61s 6s/step - accuracy: 0.6113 - loss: 142.4232 - val_accuracy: 0.9700 - val_loss: 3.2845
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9617 - loss: 3.0699 - val_accuracy: 0.9760 - val_loss: 2.5734
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9653 - loss: 3.3800 - val_accuracy: 0.9760 - val_loss: 1.9767
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9612 - loss: 2.9527 - val_accuracy: 0.9620 - val_loss: 4.3105
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8227 - loss: 44.3675 - val_accuracy: 0.9740 - val_loss: 3.5917
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9727 - loss: 2.5202 - val_accuracy: 0.9770 - val_loss: 2.9208
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9785 - loss: 1.8782 - val_accuracy: 0.9770 - val_loss: 3.8027
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9756 - loss: 1.2988 - val_accuracy: 0.9820 - val_loss: 1.8187
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9479 - loss: 10.1749 - val_accuracy: 0.9780 - val_loss: 4.0042
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9906 - loss: 0.5254 - val_accuracy: 0.9810 - val_loss: 2.8682
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9756 - loss: 1.9075 - val_accuracy: 0.9780 - val_loss: 2.0368
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9818 - loss: 1.3016 - val_accuracy: 0.9740 - val_loss: 3.4342
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9834 - loss: 1.7561 - val_accuracy: 0.9810 - val_loss: 2.7756
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9623 - loss: 5.1741 - val_accuracy: 0.9540 - val_loss: 7.9315
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.9739 - loss: 3.2275 - val_accuracy: 0.9800 - val_loss: 3.0413
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9878 - loss: 0.7286 - val_accuracy: 0.9840 - val_loss: 2.3123
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9884 - loss: 0.3423 - val_accuracy: 0.9820 - val_loss: 3.0953
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9855 - loss: 1.0400 - val_accuracy: 0.9750 - val_loss: 3.9809
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9749 - loss: 2.1095 - val_accuracy: 0.9770 - val_loss: 3.4691
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9810 - loss: 1.6447 - val_accuracy: 0.9090 - val_loss: 21.2408
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9351 - loss: 10.3197 - val_accuracy: 0.9780 - val_loss: 4.2019
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9892 - loss: 0.6700 - val_accuracy: 0.9850 - val_loss: 2.3108
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9900 - loss: 0.5019 - val_accuracy: 0.9810 - val_loss: 2.9075
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9879 - loss: 0.7096 - val_accuracy: 0.9540 - val_loss: 8.8453
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9520 - loss: 5.6856 - val_accuracy: 0.9800 - val_loss: 2.6423
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9919 - loss: 0.7711 - val_accuracy: 0.9780 - val_loss: 2.6843
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9903 - loss: 0.7820 - val_accuracy: 0.9770 - val_loss: 2.8368
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9894 - loss: 1.1260 - val_accuracy: 0.9800 - val_loss: 2.8684
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9840 - loss: 1.2812 - val_accuracy: 0.9760 - val_loss: 3.0064
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9837 - loss: 1.2223 - val_accuracy: 0.9780 - val_loss: 3.4054
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9893 - loss: 0.6354 - val_accuracy: 0.9750 - val_loss: 2.8365
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9487 - loss: 5.5880 - val_accuracy: 0.9760 - val_loss: 2.6630
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9892 - loss: 0.7901 - val_accuracy: 0.9800 - val_loss: 2.1613
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9906 - loss: 0.6876 - val_accuracy: 0.9550 - val_loss: 7.0392
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9797 - loss: 1.7234 - val_accuracy: 0.9770 - val_loss: 2.1295
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 74s 10s/step - accuracy: 0.9901 - loss: 0.6844 - val_accuracy: 0.9800 - val_loss: 2.9547
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9863 - loss: 0.8584 - val_accuracy: 0.9780 - val_loss: 1.9598
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9856 - loss: 0.6705 - val_accuracy: 0.9780 - val_loss: 2.5713
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9920 - loss: 0.5405 - val_accuracy: 0.9800 - val_loss: 2.5881
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9905 - loss: 0.4826 - val_accuracy: 0.9810 - val_loss: 1.3669
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9905 - loss: 0.4905 - val_accuracy: 0.9630 - val_loss: 5.2326
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9798 - loss: 1.4123 - val_accuracy: 0.9790 - val_loss: 1.8976
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.9856 - loss: 0.8678 - val_accuracy: 0.9760 - val_loss: 2.8497
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9890 - loss: 0.6056 - val_accuracy: 0.9840 - val_loss: 1.8813
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.9929 - loss: 0.2993 - val_accuracy: 0.9820 - val_loss: 1.4930
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9944 - loss: 0.2849 - val_accuracy: 0.9770 - val_loss: 2.8742
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9854 - loss: 1.0806 - val_accuracy: 0.9720 - val_loss: 3.1060
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9876 - loss: 0.7099 - val_accuracy: 0.9800 - val_loss: 2.3242
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9935 - loss: 0.5197 - val_accuracy: 0.9760 - val_loss: 2.5873
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9826 - loss: 1.0170 - val_accuracy: 0.9880 - val_loss: 1.2650

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model(
    "feature_extraction_with_data_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 4/4 [==============================] - 5s 891ms/step - loss: 2.6262 - accuracy: 0.9730
# Test accuracy: 0.973

# %% [markdown]
# ### Fine-tuning a pretrained model

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# **Freezing all layers until the fourth from the last**

# %%
conv_base.trainable = True
for layer in conv_base.layers[:-4]:
    layer.trainable = False

# %% [markdown]
# **Fine-tuning the model**

# %%
model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.RMSprop(learning_rate=1e-5),
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 8/8 [==============================] - 20s 2s/step - loss: 0.3781 - accuracy: 0.9915 - val_loss: 1.5247 - val_accuracy: 0.9830
# Epoch 2/30
# 8/8 [==============================] - 18s 2s/step - loss: 0.2182 - accuracy: 0.9955 - val_loss: 1.5562 - val_accuracy: 0.9800
# Epoch 3/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.2731 - accuracy: 0.9925 - val_loss: 2.0238 - val_accuracy: 0.9830
# Epoch 4/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.0551 - accuracy: 0.9960 - val_loss: 1.9239 - val_accuracy: 0.9830
# Epoch 5/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.2878 - accuracy: 0.9920 - val_loss: 2.0049 - val_accuracy: 0.9820
# Epoch 6/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.2885 - accuracy: 0.9940 - val_loss: 1.8386 - val_accuracy: 0.9820
# Epoch 7/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.1137 - accuracy: 0.9960 - val_loss: 1.8267 - val_accuracy: 0.9810
# Epoch 8/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.1918 - accuracy: 0.9945 - val_loss: 1.8045 - val_accuracy: 0.9830
# Epoch 9/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.1915 - accuracy: 0.9965 - val_loss: 1.7921 - val_accuracy: 0.9820
# Epoch 10/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.0287 - accuracy: 0.9980 - val_loss: 1.7697 - val_accuracy: 0.9780
# Epoch 11/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.1590 - accuracy: 0.9955 - val_loss: 1.8114 - val_accuracy: 0.9790
# Epoch 12/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.1850 - accuracy: 0.9945 - val_loss: 1.8713 - val_accuracy: 0.9780
# Epoch 13/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.1165 - accuracy: 0.9950 - val_loss: 1.8501 - val_accuracy: 0.9810
# Epoch 14/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.3398 - accuracy: 0.9940 - val_loss: 1.9135 - val_accuracy: 0.9750
# Epoch 15/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.1481 - accuracy: 0.9945 - val_loss: 1.7213 - val_accuracy: 0.9800
# Epoch 16/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.1820 - accuracy: 0.9960 - val_loss: 1.7068 - val_accuracy: 0.9820
# Epoch 17/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.1472 - accuracy: 0.9965 - val_loss: 2.1636 - val_accuracy: 0.9760
# Epoch 18/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.1514 - accuracy: 0.9945 - val_loss: 1.6248 - val_accuracy: 0.9790
# Epoch 19/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.1317 - accuracy: 0.9960 - val_loss: 1.8496 - val_accuracy: 0.9820
# Epoch 20/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.1043 - accuracy: 0.9965 - val_loss: 1.5342 - val_accuracy: 0.9820
# Epoch 21/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.0799 - accuracy: 0.9970 - val_loss: 1.5950 - val_accuracy: 0.9830
# Epoch 22/30
# 8/8 [==============================] - 18s 2s/step - loss: 0.0148 - accuracy: 0.9990 - val_loss: 1.8047 - val_accuracy: 0.9820
# Epoch 23/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.1027 - accuracy: 0.9965 - val_loss: 1.9337 - val_accuracy: 0.9750
# Epoch 24/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.0480 - accuracy: 0.9985 - val_loss: 1.4677 - val_accuracy: 0.9840
# Epoch 25/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.0453 - accuracy: 0.9975 - val_loss: 1.6363 - val_accuracy: 0.9830
# Epoch 26/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.1584 - accuracy: 0.9950 - val_loss: 1.6014 - val_accuracy: 0.9780
# Epoch 27/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.1795 - accuracy: 0.9955 - val_loss: 1.6203 - val_accuracy: 0.9840
# Epoch 28/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.1733 - accuracy: 0.9945 - val_loss: 1.6613 - val_accuracy: 0.9790
# Epoch 29/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.0330 - accuracy: 0.9970 - val_loss: 1.6132 - val_accuracy: 0.9810
# Epoch 30/30
# 8/8 [==============================] - 17s 2s/step - loss: 0.0131 - accuracy: 0.9995 - val_loss: 1.5453 - val_accuracy: 0.9820

# %%
model = keras.models.load_model("fine_tuning.keras")
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 4/4 [==============================] - 5s 888ms/step - loss: 2.0943 - accuracy: 0.9760
# Test accuracy: 0.976

# %% [markdown]
# ## Summary
